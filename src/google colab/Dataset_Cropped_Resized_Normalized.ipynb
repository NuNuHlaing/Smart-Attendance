# %% [markdown]
# # Dataset_Cropped_Resized_Normalized
# Dataset : https://www.kaggle.com/datasets/vishesh1412/celebrity-face-image-dataset

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)

# %%
# google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random

# Load the Haar Cascade classifier
face_cascade = cv2.CascadeClassifier('/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/haarcascades/haarcascade_frontalface_default.xml')

# %%
# Global variable to track the total number of saved faces within each folder
total_faces_saved = 0

# Function to detect, resize, normalize, and save faces from an input image
def detect_resize_normalize_save(input_image_path, output_folder_path, target_size=(400, 400)):
    global total_faces_saved

    # Read the input image
    img = cv2.imread(input_image_path)

    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    # Detect faces in the input image
    faces = face_cascade.detectMultiScale(gray, 1.3, 4)
    print(f'Number of detected faces in {input_image_path}: {len(faces)}')

    # Create the output folder if it doesn't exist
    os.makedirs(output_folder_path, exist_ok=True)

    # Extract the folder name from the input_image_path
    folder_name = os.path.basename(os.path.dirname(input_image_path))

    # Loop over all detected faces
    if len(faces) > 0:
        for i, (x, y, w, h) in enumerate(faces):
            # Crop the face region
            face = img[y:y + h + 15, x:x + w + 15]

            # Create a new image with grey background
            grey_background = np.ones_like(face) * 128

            # Get the dimensions of the face region
            face_height, face_width, _ = face.shape

            # Calculate the position to paste the face on the grey background
            paste_x = (grey_background.shape[1] - face_width) // 2
            paste_y = (grey_background.shape[0] - face_height) // 2

            # Paste the face on the grey background
            grey_background[paste_y:paste_y + face_height, paste_x:paste_x + face_width] = face

            # Resize the face to the target size
            resized_face = cv2.resize(grey_background, target_size)

            # Normalize the pixel values to the range [0, 1]
            normalized_face = resized_face.astype(np.float32) / 255.0

            # Save the normalized face with folder name and auto index starting from 1
            output_file_path = os.path.join(output_folder_path, f'{folder_name}_face{total_faces_saved + 1}.jpg')
            cv2.imwrite(output_file_path, (normalized_face * 255.0).astype(np.uint8))
            print(f"{output_file_path} is saved")

            # Increment the total_faces_saved count within each folder
            total_faces_saved += 1

    cv2.waitKey(0)
    cv2.destroyAllWindows()

# List of input folder names containing the images
input_image_folders = ['/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie',
                       '/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith',
                       '/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Nu Nu Hlaing']

# List of corresponding output folder paths
output_folder_paths = ['/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie',
                       '/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith',
                       '/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing']

# Reset the total_faces_saved count for each folder
for _ in range(len(input_image_folders)):
    input_folder = input_image_folders[_]
    image_files = os.listdir(input_folder)
    total_faces_saved = 0

    # Process each image in the input folder
    for image_file in image_files:
        image_path = os.path.join(input_folder, image_file)
        detect_resize_normalize_save(image_path, output_folder_paths[_])
# Out:
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/029_f2882b0d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face1.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/021_6e419870.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face2.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/038_e40d5b16.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face3.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/020_4c4b655f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face4.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/019_57ab290d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face5.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/037_62d00a09.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face6.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/030_66bddeb6.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face7.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/027_58887f30.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face8.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/028_6a0ff8de.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face9.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/017_e28ea9d4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face10.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/026_2828fcaf.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face11.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/015_8bac79b5.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face12.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/018_fcafe1a8.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face13.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/024_ca32be97.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face14.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/025_41cee764.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face15.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/023_7781dd1c.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face16.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/016_8945d6ca.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face17.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/022_b497b92e.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face18.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/013_95ecbd39.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face19.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/014_0d29db88.jpg: 2
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face20.jpg is saved
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face21.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/011_7344ca35.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face22.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/012_cfcd4007.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face23.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/007_cabbfcbb.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face24.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/003_57612506.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face25.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/002_8f8da10e.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face26.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/010_f99d79e3.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face27.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/008_d1f87068.jpg: 2
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face28.jpg is saved
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face29.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/001_fe3347c0.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face30.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/005_582c121a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face31.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/006_9135205d.jpg: 2
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face32.jpg is saved
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face33.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/004_f61e7d0c.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face34.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/079_40a598dc.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face35.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/077_27650aa3.jpg: 2
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face36.jpg is saved
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face37.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/087_f325890f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face38.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/078_044866e7.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face39.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/068_2fb110d1.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/076_1d914d5b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face40.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/064_0de68937.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face41.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/065_689150aa.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face42.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/074_0ec79719.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face43.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/067_ff52c2fe.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face44.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/063_c486d5ef.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face45.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/072_8d068904.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face46.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/073_9f1d377a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face47.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/070_1a4312d2.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face48.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/066_b378479b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face49.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/071_b537dbca.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face50.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/062_6aa9cf8f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face51.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/069_9d0e44d5.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face52.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/061_e18ba2b0.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/059_df425619.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face53.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/051_268fdfd7.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face54.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/052_6db5f5bf.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face55.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/060_4037f0f7.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face56.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/058_02860eff.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face57.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/049_4d6df392.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face58.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/053_05c78fa1.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face59.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/057_7f34f0f4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face60.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/055_aaaf063c.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face61.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/056_97412d14.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face62.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/043_b812749f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face63.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/042_2ccd070f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face64.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/045_c560251e.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face65.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/046_d93a2c2d.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/034_418fbbdb.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face66.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/033_23e68208.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face67.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/044_512dfd33.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face68.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/035_2e497561.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face69.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/047_5350c8c0.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face70.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/054_7ba62f81.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face71.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/048_0a32a483.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face72.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/050_7c5b026c.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face73.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/031_2364f4d8.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face74.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/041_abf5c9cb.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face75.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/036_3e807a88.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face76.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/032_db66bd61.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face77.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/039_6b10ab98.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face78.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/098_dd1405fc.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face79.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/097_9a6bf61f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face80.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/100_31ff9373.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face81.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/080_e998ab00.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/086_f2c730f3.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face82.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/081_12fb31ec.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face83.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/095_0be163a1.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/096_75710434.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face84.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/094_c255b703.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face85.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/093_6ce62543.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face86.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/084_da751ddd.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face87.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/091_b5b4a62f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face88.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/089_33e36564.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face89.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/085_f579db33.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face90.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/082_047778bb.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face91.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Angelina Jolie/088_029ffc54.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Angelina Jolie/Angelina Jolie_face92.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/033_46c95715.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face1.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/022_a8206d1a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face2.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/025_25dc7dcf.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face3.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/026_805241a7.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face4.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/023_98d91529.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face5.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/032_fd37a8e2.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face6.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/031_8fc10a75.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face7.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/027_78f200c3.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face8.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/020_45c8d790.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face9.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/021_143b276f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face10.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/013_0c83ca91.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face11.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/006_87166f38.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face12.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/007_74ccfb4a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face13.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/008_31e90c6b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face14.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/019_ddcd5687.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face15.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/018_136dbb40.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face16.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/017_4748675b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face17.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/016_8bb23f7e.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face18.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/014_871b0d80.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face19.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/011_270cd3ea.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face20.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/010_08c44431.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face21.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/012_8de7a736.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face22.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/015_82889ec9.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face23.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/005_02ab3a1b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face24.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/004_777c50d0.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face25.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/003_7a6b2156.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face26.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/002_cc1b9701.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face27.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/001_c04300ef.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face28.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/086_8274c0d1.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face29.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/080_569bb446.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face30.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/081_4d677d83.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face31.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/087_155f1f74.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face32.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/085_5c4b6432.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face33.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/075_a7a83d60.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face34.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/074_6f4720aa.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/072_da45cf8f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face35.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/058_ca613f72.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face36.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/061_38d21dc0.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face37.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/063_a90951c4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face38.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/073_aa4e37e8.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face39.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/069_8533eee4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face40.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/053_be062c12.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face41.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/048_185402c6.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face42.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/071_2d51687a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face43.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/067_571d88eb.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face44.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/066_1867585d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face45.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/059_ef2c0ca7.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/056_8362ff51.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face46.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/055_14a5e7bc.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face47.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/065_34848907.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face48.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/064_213e2850.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face49.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/047_80045019.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face50.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/054_9f01aefa.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face51.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/052_b80b0a3f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face52.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/057_545ca96d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face53.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/045_6895fe7e.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face54.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/041_cc0957bf.jpg: 2
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face55.jpg is saved
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face56.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/051_fd8a292f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face57.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/050_3e39c960.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face58.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/049_31625c44.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face59.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/044_ac060de4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face60.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/043_6973a308.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face61.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/042_8030e553.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face62.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/040_9b4bfe5b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face63.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/046_8bf34269.jpg: 2
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face64.jpg is saved
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face65.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/039_1c018deb.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face66.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/037_b5467841.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face67.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/038_5e10a567.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face68.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/036_5e0af3bf.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face69.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/024_54112f36.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face70.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/035_a767728d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face71.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/030_716e4856.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face72.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/029_36dac19e.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face73.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/034_984e63b3.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face74.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/099_151b7575.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face75.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/097_df404aa1.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face76.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/094_16e562f0.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face77.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/079_e3171916.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face78.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/078_b546dff5.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face79.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/096_b096ebfe.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face80.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/100_f4b2c7a7.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/095_1104d364.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face81.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/098_36dd62c5.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face82.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/092_22d9de5d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face83.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/093_c4d318cd.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face84.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/083_d6f1d5ac.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face85.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/077_ddf0abd8.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face86.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Brad Pitt/090_12e1f614.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Brad Pitt/Brad Pitt_face87.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Johnny Depp/013_f44c68a1.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Johnny Depp/Johnny Depp_face1.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Johnny Depp/020_6b7d8470.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Johnny Depp/Johnny Depp_face2.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Johnny Depp/019_3eb26944.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Johnny Depp/Johnny Depp_face3.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Johnny Depp/014_68248214.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Johnny Depp/Johnny Depp_face4.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Johnny Depp/017_aadefe7b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Johnny Depp/Johnny Depp_face5.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Johnny Depp/016_8b4d3698.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Johnny Depp/Johnny Depp_face6.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Johnny Depp/027_2eab41f9.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Johnny Depp/Johnny Depp_face7.jpg is saved
# ...
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/048_bf9c2b11.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/046_6d5b1ed6.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face17.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/090_e959664a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face18.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/076_d36850ba.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/074_61fe25d9.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face19.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/089_97f39eb8.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face20.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/088_d6c5d9f4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face21.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/081_8dc3b149.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face22.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/084_0d8b77bc.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/070_6743629d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face23.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/073_f04cd664.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face24.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/082_ed9a24cc.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face25.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/032_2899cee6.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face26.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/027_803986e2.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face27.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/029_09dcae68.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face28.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/071_5f7cdaaf.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face29.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/069_80468bd5.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face30.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/004_af9b4c7c.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face31.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/009_a023db5b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face32.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/001_beebcee2.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face33.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/011_0e0e8b1c.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face34.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/005_37066c18.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face35.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/007_9656ae64.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face36.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/019_33ab99af.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face37.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/015_8da65114.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face38.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/016_d9c576a4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face39.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/017_bb6ad7d6.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face40.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/020_8e6bdc45.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face41.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/012_19e90fb6.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face42.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/002_078f6fe5.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face43.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/006_bbb6978e.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face44.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/008_cdaf39e7.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face45.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/010_8bd7dba1.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face46.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/013_19a43131.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/021_3cf2aa92.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face47.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/018_d5d389eb.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face48.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/003_936c5a43.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face49.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/039_3daa67cf.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face50.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/041_bcfa1766.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face51.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/040_630a0d6a.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/025_0dc3ad3d.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face52.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/037_17e4f89a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face53.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/026_4f5bfb2c.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/042_f6cff42f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face54.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/028_05df393f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face55.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/034_32b04ae9.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face56.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/023_cb306a1a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face57.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/043_33815e76.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face58.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/036_8751d89b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face59.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/033_241ed413.jpg: 2
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face60.jpg is saved
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face61.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/031_7ad763d7.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face62.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/038_b28dda4c.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face63.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/022_c9c4cb9f.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face64.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/035_9e22f213.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/024_b222784a.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face65.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/057_faaa39ed.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face66.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/058_38b80eed.jpg: 0
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/056_abd6e06b.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face67.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/047_dc7e1839.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face68.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/044_988edbe9.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face69.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/054_cbee29ae.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face70.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Will Smith/060_8bb5cac3.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Will Smith/Will Smith_face71.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Nu Nu Hlaing/NNH2.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face1.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Nu Nu Hlaing/NNH4.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face2.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Nu Nu Hlaing/NNH1.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face3.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Nu Nu Hlaing/NNH3.png: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face4.jpg is saved
# Number of detected faces in /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset/Nu Nu Hlaing/NNH5.jpg: 1
# /content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face5.jpg is saved

# %% [markdown]
# # Create 500 different style image variations

# %%
import cv2
from PIL import Image, ImageEnhance, ImageFilter

def apply_random_style(image_path):
    # Load the image using OpenCV and convert it to a Pillow image
    opencv_image = cv2.imread(image_path)

    # Randomly select and apply different image processing styles
    # Example styles: brightness, contrast, sharpness, rotation, flipping, etc.
    pillow_image = apply_random_brightness(pillow_image)
    pillow_image = apply_random_contrast(pillow_image)
    pillow_image = apply_random_sharpness(pillow_image)
    pillow_image = apply_random_rotation(pillow_image)
    pillow_image = apply_random_flip(pillow_image)
    pillow_image = apply_random_filter(pillow_image)

    return pillow_image

def apply_random_brightness(image):
    enhancer = ImageEnhance.Brightness(image)
    factor = random.uniform(0.7, 1.3)
    return enhancer.enhance(factor)

def apply_random_contrast(image):
    enhancer = ImageEnhance.Contrast(image)
    factor = random.uniform(0.7, 1.3)
    return enhancer.enhance(factor)

def apply_random_sharpness(image):
    enhancer = ImageEnhance.Sharpness(image)
    factor = random.uniform(0.0, 2.0)
    return enhancer.enhance(factor)

def apply_random_rotation(image):
    angle = random.uniform(-15, 15)
    return image.rotate(angle)

def apply_random_flip(image):
    if random.random() < 0.5:
        return image.transpose(Image.FLIP_LEFT_RIGHT)
    else:
        return image.transpose(Image.FLIP_TOP_BOTTOM)

def apply_random_filter(image):
    filters = [ImageFilter.BLUR, ImageFilter.EDGE_ENHANCE, ImageFilter.EMBOSS]
    selected_filter = random.choice(filters)
    return image.filter(selected_filter)

if __name__ == "__main__":
    input_images = [
        "/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face1.jpg",
        "/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face2.jpg",
        "/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face3.jpg",
        "/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face4.jpg",
        "/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing/Nu Nu Hlaing_face5.jpg",
    ]

    # Create an output directory to store the generated images
    os.makedirs("output", exist_ok=True)

    # Create 500 different style image variations
    for i in range(1, 501):
        # Choose a random input image
        #random_image = random.choice(input_images)
        #output_image = apply_random_style(random_image)

        # Choose a random input image
        random_image_path = random.choice(input_images)

        # Load the image using Pillow directly
        pillow_image = Image.open(random_image_path)

        # Apply random image processing styles
        pillow_image = apply_random_brightness(pillow_image)
        pillow_image = apply_random_contrast(pillow_image)
        pillow_image = apply_random_sharpness(pillow_image)
        pillow_image = apply_random_rotation(pillow_image)
        pillow_image = apply_random_flip(pillow_image)
        pillow_image = apply_random_filter(pillow_image)

        # Save the generated image with a dynamic index
        output_path = os.path.join("output", f"NNH{i}.jpg")
        pillow_image.save(output_path)

# %% [markdown]
# # Download Folder

# %%
import os
import shutil

folder_name = 'output'

# Create a zip archive of the folder
zip_file_name = f'{folder_name}.zip'
shutil.make_archive(zip_file_name, 'zip', f'/content/{folder_name}')

# Move the zip archive to the /content directory
shutil.move(zip_file_name + '.zip', '/content/' + zip_file_name)

# Provide a link to download the zip archive
print(f"Click the link to download the zip archive: /content/{zip_file_name}")
# Out:
# Click the link to download the zip archive: /content/output.zip

# %% [markdown]
# # Change File Name all at once

# %%
def rename_images_with_auto_index(directory):
    image_extensions = (".jpg", ".jpeg", ".png", ".gif", ".bmp")

    # Get a list of image files in the directory
    image_files = [file for file in os.listdir(directory) if file.lower().endswith(image_extensions)]

    # Sort the files by their name to ensure consistent ordering
    image_files.sort()

    # Rename files with auto index
    for i, image_file in enumerate(image_files):
        base_name, extension = os.path.splitext(image_file)
        new_name = f"Nu Nu Hlaing_face{i}{extension}"
        old_path = os.path.join(directory, image_file)
        new_path = os.path.join(directory, new_name)
        os.rename(old_path, new_path)

if __name__ == "__main__":
    # Replace 'YOUR_DIRECTORY_PATH' with the path to the directory containing your images
    directory_path = "/content/drive/MyDrive/Smart Attendance (CV-Batch-7 )/Dataset_Cropped_Resized_Normalized/Nu Nu Hlaing"
    rename_images_with_auto_index(directory_path)
